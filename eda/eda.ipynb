# %% [markdown]
# # EDA – Online Retail II
# Load, clean, and visualise dataset.

# %%
import pandas as pd

df = pd.read_excel('../data/online_retail_II.xlsx', sheet_name='Year 2010-2011')

df.head()
